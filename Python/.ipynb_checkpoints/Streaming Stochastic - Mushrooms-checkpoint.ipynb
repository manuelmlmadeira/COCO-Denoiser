# %%
import numpy as np
from scipy.linalg import norm
import matplotlib.pyplot as plt
from scipy.optimize import line_search
from scipy.optimize import minimize
# %matplotlib inline
from sklearn.datasets import load_svmlight_file
from scipy.sparse import csr_matrix
def get_data(dataname):
    data = load_svmlight_file(dataname)
    return data[0], data[1]
from logistic_linear import *
import random
import math
import time

# %% [markdown]
# <a id='loss'></a>
# ## 1. Loss functions, gradients and step-sizes
#
#
# We want to minimize
# $$
# \frac 1n \sum_{i=1}^n \ell(a_i^\top x, b_i) + \frac \lambda 2 \|x\|_2^2
# $$
# where
# - $\ell(z, b) = \log(1 + \exp(-bz))$ (logistic regression).
#
# We write it as a minimization problem of the form
# $$
# \frac 1n \sum_{i=1}^n f_i(x)
# $$
# where
# $$
# f_i(x) = \ell(a_i^\top x, b_i) + \frac \lambda 2 \|x\|_2^2.
# $$
#
# The gradients
# $$
# \nabla f_i(x) = - \frac{b_i}{1 + \exp(b_i a_i^\top x)} a_i + \lambda x.
# $$
#
# Denote by $L$ (resp. $L_i$) the Lipschitz constant of $f$ (resp. $f_i$) and $\mathbf A^\top = [a_1, \ldots, a_n].$
# One can easily see (using $\|\cdot\|_{2}$ for the matrix spectrale norm) that
# $$
# L = \frac{ \|\mathbf A^\top \mathbf A \|_{2}}{4 n} + \lambda \quad \text{ and } L_i = \frac 14 \| a_i \|_2^2 + \lambda.
# $$
# For full-gradient methods, the theoretical step-size is $1 / L$, while for SAG and SVRG (see below) it can be taken as
# $1 / (\max_{i=1,\ldots,n} L_i)$

# %% [markdown]
# <a id='data'></a>
# ## 2. Generate a dataset
#
# We generate datasets for the least-squares and the logistic cases. First we define a function for the least-squares case.

# %%
# Logistic Regression
loss = loss_logreg
grad = grad_logreg
grad_i = grad_i_logreg
lipschitz_constant = lipschitz_logreg
mu_constant = mu_constant_logreg

dataname = "mushrooms"   
A, b = get_data(dataname)
n, d = A.shape;
A = A.toarray()
print("Size of the Dataset (n, d) = ", n, d)

# Setup
n_iter = 45
x_0 = 1*np.ones(d)
lbda = 1.00001 / n ** (0.5) #0 #1 #1.00001 / n ** (0.5) 
store_every = n

# Initialization
mu = mu_constant(A, b, lbda) #0.011094797642331011  
L = lipschitz_constant(A, b, lbda) #2.5973090315467626#
print("\lambda = %s" % lbda)
print("\mu = %s" % mu )
print("L = %s" % L )

### Get a very precise minimum to compute distances to minimum

from scipy.optimize import check_grad
check_grad(loss, grad, np.random.randn(d), A, b, lbda)
from scipy.optimize import fmin_l_bfgs_b

x_init = np.zeros(d)
x_min, f_min, _ = fmin_l_bfgs_b(loss, x_init, grad,
                                args=(A, b, lbda), pgtol=1e-30, factr=1e-30)

gradient_memory = np.zeros((n, d))
g_norm = np.zeros(n)
for j in range(n):
    gradient_memory[j] = grad_i(j, x_min, A, b ,lbda)
    g_norm[j] = norm(gradient_memory[j])
    
plt.plot(g_norm)
# Out:
# Size of the Dataset (n, d) =  8124 112
# \lambda = 0.011094797642331011
# \mu = 0.011094797642331011
# L = 2.5973090315467626
# 5.2325709472501554e-11
# [1.67696937e-03 1.57726580e-02 1.71691390e-01 6.21539689e-02
#  1.15893284e-04 1.88410016e-01 1.84656426e-01 1.60783765e-01
#  1.06769783e-03 9.33130074e-02 5.01712833e-03 1.86228687e-02
#  7.92965979e-02 9.07614030e-02 1.05718725e-01 1.48092559e-02
#  4.75964729e-05 4.75964729e-05 5.20338745e-02 7.34658500e-02
#  1.05704664e-01 3.34116232e-01 2.40076992e-03 2.58243346e-02
#  2.07778677e-01 1.36208561e-02 2.40076992e-03 5.39737665e-02
#  3.52596319e-02 4.92810450e-02 4.92810450e-02 1.44579395e-02
#  4.25362957e-01 4.07139416e-01 3.26814799e-02 2.26589944e-01
#  2.13230952e-01 1.40667758e-01 1.43829251e-03 5.62759358e-02
#  5.71801789e-02 1.17493568e-02 2.14649585e-03 2.30211917e-02
#  7.45638846e-02 5.17745729e-03 8.96012323e-03 4.73765874e-02
#  1.12636346e-02 2.45923418e-01 1.93897479e-01 4.62669224e-03
# ...

# %% [markdown]
# # SGD

# %%
from stochastic_methods import str_sgd
np.random.seed(0)
max_squared_sum = np.max(np.sum(A ** 2, axis=1))
L_i_max = 0.25 * max_squared_sum + lbda

n_reps = 50
x_init = x_min + x_0.copy()* 0.5*10**(-1) #x_min - x_0.copy() * 1.25* 10**(-2) 
step_size = 1/L * 2   #2.5 * 1/(L)*1000000000   #1/L_i_max  #1.0 / (10*max_squared_sum + lbda)
store_every = 1
n_steps = 1000
print('dimension:', d)
#print(x_init)
#print(x_min)
print("n:", n)

print("SGD step-size = %s" % step_size)
visited_distances_str_sgd = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    #t = time.time()
    rep_x_final, rep_visited_points = str_sgd(n, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_sgd[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)
    #elapsed = time.time() - t
    #print(elapsed)
        
#print(visited_distances_str_sgd[:,1999])
print(visited_distances_str_sgd)
# Out:
# dimension: 112
# n: 8124
# SGD step-size = 0.7700277385971857
# 25
# 50
# [[0.52915026 0.51736122 0.50586629 ... 0.09311667 0.08786398 0.09145287]
#  [0.52915026 0.51737116 0.50579791 ... 0.10890761 0.10270917 0.10696822]
#  [0.52915026 0.52269109 0.51107364 ... 0.1023132  0.10323021 0.11146319]
#  ...
#  [0.52915026 0.5227522  0.51647434 ... 0.08476958 0.08345108 0.08676391]
#  [0.52915026 0.52118352 0.51841574 ... 0.1247603  0.1238711  0.12732481]
#  [0.52915026 0.52122908 0.51283549 ... 0.1088224  0.11061844 0.11023468]]

# %%
from stochastic_methods import str_sgd_COCO
np.random.seed(0)

K = 2
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_sgd_COCO2 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_sgd_COCO(n, K, L, tol, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_sgd_COCO2[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_sgd_COCO2)
#monitor_str_COCO2 = monitor(str_sgd_COCO, loss, x_min, (A, b ,lbda))
#monitor_str_COCO2.run(K, L, tol, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))

# %%
from stochastic_methods import str_sgd_COCO
np.random.seed(0)

K = 4
L = L
tol= 10**(0)
print("tolerance = %s" % tol)
print("SGD step-size = %s" % step_size)
visited_distances_str_sgd_COCO4 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    t = time.time()
    rep_x_final, rep_visited_points = str_sgd_COCO(n, K, L, tol, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_sgd_COCO4[rep, :] = rep_visited_distances
    #if (rep+1) % 1 == 0:
    #    print(rep+1)
    elapsed = time.time() - t
    print("rep:", rep+1, "- time:", elapsed)

print(visited_distances_str_sgd_COCO4)

# %%
from stochastic_methods import str_sgd_COCO
np.random.seed(0)
K = 8
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_sgd_COCO8 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    t = time.time()
    rep_x_final, rep_visited_points = str_sgd_COCO(n, K, L, tol, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_sgd_COCO8[rep, :] = rep_visited_distances
    #if (rep+1) % 1 == 0:
        #print(rep+1)
    elapsed = time.time() - t
    print("rep:", rep+1, "- time:", elapsed)

print(visited_distances_str_sgd_COCO8)

# %%
from stochastic_methods import str_sgd_COCO
np.random.seed(0)

K = 16
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_sgd_COCO16 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_sgd_COCO(n, K, L, tol, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_sgd_COCO16[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_sgd_COCO16)

# %%
# Ver se os s0 gerados são diferentes com e sem WS (talvez seja melhor no fourclass para conseguir ver os s0)

# %%
def plot_epochs(visited_distances_mtxs, solvers):
    
    fig, ax = plt.subplots(figsize=(20, 12))
    linestyles = ['-', '--', '--', '-.', ':', '--', '-']
    ls = 0
    x = np.arange(n_steps+1)
    for mtx in visited_distances_mtxs:
        mean = np.mean(mtx, axis=0)
        std = np.std(mtx, axis=0)/math.sqrt(n_reps)
        #print(mean)
        #print(std)
        
        ax.errorbar(x, mean, xerr=0, yerr=std, linestyle=linestyles[ls])
        #plt.semilogy(mean, lw=2, linestyle = linestyles[ls])
        #ax.set_title('Logistic Regression - Streaming 1st Order')
        ax.set_yscale('log')
        ls +=1
        
    
    #from matplotlib.ticker import ScalarFormatter, NullFormatter
    #for axis in [ax.yaxis]:
    #    axis.set_major_formatter(ScalarFormatter())
    #    axis.set_minor_formatter(NullFormatter())
        
    #print(plt.yticks())
    plt.xlabel("Oracle Consultations", fontsize=40)#, fontsize=20)
    plt.ylabel("$E[\|x_k - x^*\|_2]$ ", fontsize=40)#, fontsize=20)
    
    #plt.yticks(ticks=[1.e-1, 2.e-1, 3.e-1, 4.e-1, 5.e-1], labels = [r"$1 \times 10^{-1}$", r"$2 \times 10^{-1}$", r"$3 \times 10^{-1}$", r"$4 \times 10^{-1}$", r"$5 \times 10^{-1}$"])
    #print(plt.yticks())
    plt.xticks(fontsize=40)
    plt.yticks(fontsize=40)
    plt.legend(solvers, fontsize=40)
    plt.xlim([0, 1000])
    plt.ylim([9*10**(-2), 1*10**(0)])
    #plt.savefig('mushrooms_SGD.png')
    print(plt.yticks())
    plt.savefig('mushrooms_SGD.pdf', bbox_inches='tight')

monitors = [visited_distances_str_sgd, visited_distances_str_sgd_COCO2, visited_distances_str_sgd_COCO4, visited_distances_str_sgd_COCO8]#, visited_distances_str_sgd_COCO16]#,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4, ]#, monitor_sag] #monitor_gd, monitor_agd,   
solvers = ["SGD","SGD$+$COCO$_2$", "SGD$+$COCO$_4$", "SGD$+$COCO$_8$", "SGD$+$COCO$_{16}$"]#, "adamCOCO$_4$", "adamCOCO$_8$", "adamCOCO$_{16}$"]#, "STRSAGA1", "STRSAGA2", "STRSAGA4"]#, "$SAG$"] #"GD", "AGD"    
plot_epochs(monitors, solvers)
# Out:
# (array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01]), <a list of 5 Text yticklabel objects>)

# %%
#NO WS
15
building: 0.005294084548950195
FDPG: 18.982221841812134
recovering primal: 1.71661376953125e-05
16
building: 0.0052258968353271484
FDPG: 21.724347829818726
recovering primal: 1.811981201171875e-05
17
building: 0.00421905517578125
FDPG: 21.409801244735718
recovering primal: 1.5735626220703125e-05
18
building: 0.0051457881927490234
FDPG: 20.716495037078857
recovering primal: 1.9073486328125e-05
19
building: 0.005292654037475586
FDPG: 18.24326491355896
recovering primal: 1.430511474609375e-05
20
building: 0.005141019821166992
FDPG: 17.586899995803833
recovering primal: 1.5974044799804688e-05
21
building: 0.005135774612426758
FDPG: 18.29582977294922
recovering primal: 1.5020370483398438e-05
22
building: 0.004252910614013672
FDPG: 23.134562730789185
recovering primal: 1.3828277587890625e-05
23
building: 0.005264997482299805
FDPG: 21.18018627166748
recovering primal: 1.4066696166992188e-05
24
building: 0.00518798828125
FDPG: 22.64943289756775
recovering primal: 1.5020370483398438e-05



#WS
15
building: 0.00444483757019043
FDPG: 24.133357048034668
recovering primal: 2.09808349609375e-05
16
building: 0.007419109344482422
FDPG: 25.34523105621338
recovering primal: 1.71661376953125e-05
17
building: 0.007219791412353516
FDPG: 25.67852210998535
recovering primal: 2.5987625122070312e-05
18
building: 0.005357027053833008
FDPG: 36.4055380821228
recovering primal: 1.621246337890625e-05
19
building: 0.005609989166259766
FDPG: 22.266440868377686
recovering primal: 1.7881393432617188e-05
20
building: 0.004558086395263672
FDPG: 23.850494861602783
recovering primal: 1.5974044799804688e-05
21
building: 0.00497889518737793
FDPG: 19.45797610282898
recovering primal: 1.621246337890625e-05
22
building: 0.005052804946899414
FDPG: 22.854680061340332
recovering primal: 1.3113021850585938e-05
23
building: 0.004950046539306641
FDPG: 19.061473846435547
recovering primal: 1.811981201171875e-05
24
building: 0.0053098201751708984
FDPG: 31.411771297454834
recovering primal: 1.6689300537109375e-05

# %%
0.6 * 1000 * 25 /(60*60)

# %%
a = range(5)
print(a.tolist())
a=a[2:2+2]
print(a)

# %% [markdown]
# # accSGD

# %%
from stochastic_methods import str_accsgd
np.random.seed(0)
max_squared_sum = np.max(np.sum(A ** 2, axis=1))
L_i_max = 0.25 * max_squared_sum + lbda

n_reps = 100
x_init = x_0.copy()
step_size = 1 * 1/(L)  #1/L_i_max  #1.0 / (10*max_squared_sum + lbda)
store_every = 1
n_steps = 800
momentum_constant = 0.1
print('dimension:', d)

print("SGD step-size = %s" % step_size)
visited_distances_str_accsgd = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_accsgd(x_init,  grad_i, store_every, step_size, n_steps, momentum_constant,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_accsgd[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_accsgd)

# %%
from stochastic_methods import str_accsgd_COCO
np.random.seed(0)

K = 2
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_accsgd_COCO2 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_accsgd_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, momentum_constant, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_accsgd_COCO2[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_accsgd_COCO2)

# %%
from stochastic_methods import str_accsgd_COCO
np.random.seed(0)

K = 4
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_accsgd_COCO4 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_accsgd_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, momentum_constant, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_accsgd_COCO4[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_accsgd_COCO4)

# %%
from stochastic_methods import str_accsgd_COCO
np.random.seed(0)

K = 8
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_accsgd_COCO8 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_accsgd_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, momentum_constant, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_accsgd_COCO8[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_accsgd_COCO8)

# %%
from stochastic_methods import str_accsgd_COCO
np.random.seed(0)

K = 16
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_accsgd_COCO16 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_accsgd_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, momentum_constant, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_accsgd_COCO16[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_accsgd_COCO16)

# %%
def plot_epochs(visited_distances_mtxs, solvers):
    
    fig, ax = plt.subplots(figsize=(20, 12))
    linestyles = ['-', '--', '--', '-.', ':', '--', '-']
    ls = 0
    x = np.arange(n_steps+1)
    for mtx in visited_distances_mtxs:
        mean = np.mean(mtx, axis=0)
        std = np.std(mtx, axis=0)/math.sqrt(n_reps)
        
        ax.errorbar(x, mean, xerr=0, yerr=std, linestyle=linestyles[ls])
        #plt.semilogy(mean, lw=2, linestyle = linestyles[ls])
        #ax.set_title('Logistic Regression - Streaming 1st Order')
        ax.set_yscale('log')
        plt.xlabel("Oracle Consultations", fontsize=40)#, fontsize=20)
        plt.ylabel("$E[\|x_k - x^*\|_2]$ ", fontsize=40)#, fontsize=20)
        ls +=1

    plt.legend(solvers)
    plt.xlim([0, 800])
    plt.ylim([5*10**(-3), 2])
    plt.savefig('mushrooms_accSGD.png')

monitors = [visited_distances_str_accsgd, visited_distances_str_accsgd_COCO2, visited_distances_str_accsgd_COCO4, visited_distances_str_accsgd_COCO8, visited_distances_str_accsgd_COCO16]#,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4, ]#, monitor_sag] #monitor_gd, monitor_agd,   
solvers = ["accSGD","accSGD$+$COCO$_2$", "accSGD$+$COCO$_4$", "accSGD$+$COCO$_8$", "accSGD$+$COCO$_{16}$"]#, "adamCOCO$_4$", "adamCOCO$_8$", "adamCOCO$_{16}$"]#, "STRSAGA1", "STRSAGA2", "STRSAGA4"]#, "$SAG$"] #"GD", "AGD"    
plot_epochs(monitors, solvers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-babc9e2dd545> in <module>
#      22     plt.savefig('mushrooms_accSGD.png')
#      23
# ---> 24 monitors = [visited_distances_str_accsgd, visited_distances_str_accsgd_COCO2, visited_distances_str_accsgd_COCO4, visited_distances_str_accsgd_COCO8, visited_distances_str_accsgd_COCO16]#,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4, ]#, monitor_sag] #monitor_gd, monitor_agd,
#      25 solvers = ["accSGD","accSGD$+$COCO$_2$", "accSGD$+$COCO$_4$", "accSGD$+$COCO$_8$", "accSGD$+$COCO$_{16}$"]#, "adamCOCO$_4$", "adamCOCO$_8$", "adamCOCO$_{16}$"]#, "STRSAGA1", "STRSAGA2", "STRSAGA4"]#, "$SAG$"] #"GD", "AGD"
#      26 plot_epochs(monitors, solvers)
#
# NameError: name 'visited_distances_str_accsgd' is not defined

# %% [markdown]
# # Adam

# %%
from stochastic_methods import str_adam
np.random.seed(0)
max_squared_sum = np.max(np.sum(A ** 2, axis=1))
L_i_max = 0.25 * max_squared_sum + lbda

n_reps = 50
x_init = x_0.copy() # x_min + x_0.copy()* 0.5*10**(-1)
step_size = 10**(-1) #1/L * 2 #1/L * 80  #1/L_i_max  #1.0 / (10*max_squared_sum + lbda)
store_every = 1
n_steps = 200
beta1 = 0.9
beta2 = 0.999
epsilon = 10**(-8)
print('dimension:', d)

print("SGD step-size = %s" % step_size)
visited_distances_str_adam = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_adam(x_init, grad_i, store_every, step_size, n_steps, beta1, beta2, epsilon, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_adam[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_adam)

# %%
from stochastic_methods import str_adam_COCO
np.random.seed(0)

K = 2
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_adam_COCO2 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_adam_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, beta1, beta2, epsilon, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_adam_COCO2[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_adam_COCO2)

# %%
from stochastic_methods import str_adam_COCO
np.random.seed(0)

K = 4
L = L
tol= 10**(-3) 

print("SGD step-size = %s" % step_size)
visited_distances_str_adam_COCO4 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    t = time.time()
    rep_x_final, rep_visited_points = str_adam_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, beta1, beta2, epsilon, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_adam_COCO4[rep, :] = rep_visited_distances
    #if (rep+1) % 25 == 0:
    #    print(rep+1)
    elapsed = time.time() - t
    print("rep:", rep+1, "- time:", elapsed)

print(visited_distances_str_adam_COCO4)

# %%
from stochastic_methods import str_adam_COCO
np.random.seed(0)

K = 8
L = L
tol= 10**(1) 

print("SGD step-size = %s" % step_size)
visited_distances_str_adam_COCO8 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    t = time.time()
    rep_x_final, rep_visited_points = str_adam_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, beta1, beta2, epsilon, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_adam_COCO8[rep, :] = rep_visited_distances
    #if (rep+1) % 25 == 0:
    #    print(rep+1)
    elapsed = time.time() - t
    print("rep:", rep+1, "- time:", elapsed)

print(visited_distances_str_adam_COCO8)

# %%
from stochastic_methods import str_adam_COCO
np.random.seed(0)

K = 16
L = L
tol= 10**(1) 

print("SGD step-size = %s" % step_size)
visited_distances_str_adam_COCO16 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    t = time.time()
    rep_x_final, rep_visited_points = str_adam_COCO(K, L, tol, x_init, grad_i, store_every, step_size, n_steps, beta1, beta2, epsilon, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_adam_COCO16[rep, :] = rep_visited_distances
    if (rep+1) % 5 == 0:
        print(rep+1)
    elapsed = time.time() - t
    print("rep:", rep+1, "- time:", elapsed)
    
    
print(visited_distances_str_adam_COCO16)

# %%
def plot_epochs(visited_distances_mtxs, solvers):
    
    fig, ax = plt.subplots(figsize=(20, 12))
    linestyles = ['-', '--', '--', '-.', ':', '--', '-']
    ls = 0
    x = np.arange(n_steps+1)
    for mtx in visited_distances_mtxs:
        mean = np.mean(mtx, axis=0)
        std = np.std(mtx, axis=0)/math.sqrt(n_reps)
        
        ax.errorbar(x, mean, xerr=0, yerr=std, linestyle=linestyles[ls])
        #plt.semilogy(mean, lw=2, linestyle = linestyles[ls])
        #ax.set_title('Logistic Regression - Streaming 1st Order')
        ax.set_yscale('log')
        plt.xlabel("Gradient Evaluations", fontsize=40)
        plt.ylabel("$\|x_k - x^*\|_2$", fontsize=40)
        ls +=1

    plt.xticks(fontsize=40)
    plt.yticks(fontsize=40)
    plt.legend(solvers, fontsize=40)
    plt.xlim([0, 200])
    #plt.ylim([5*10**(-3), 2])
    plt.savefig('mushrooms_adam.pdf', bbox_inches='tight')

monitors = [visited_distances_str_adam, visited_distances_str_adam_COCO2, visited_distances_str_adam_COCO4, visited_distances_str_adam_COCO8]#, visited_distances_str_adam_COCO16]#,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4, ]#, monitor_sag] #monitor_gd, monitor_agd,   
solvers = ["Adam","Adam$+$COCO$_2$", "Adam$+$COCO$_4$", "Adam$+$COCO$_8$", "Adam$+$COCO$_{16}$"]#, "STRSAGA1", "STRSAGA2", "STRSAGA4"]#, "$SAG$"] #"GD", "AGD"    
plot_epochs(monitors, solvers)

# %%
25*200*50/(60*60)

# %% [markdown]
# # strSAGA

# %%
from stochastic_methods import str_saga
np.random.seed(0)
max_squared_sum = np.max(np.sum(A ** 2, axis=1))
L_i_max = 0.25 * max_squared_sum + lbda

n_reps = 50
x_init = x_min + x_0.copy()* 0.5*10**(-1) #x_min - x_0.copy() * 1.25* 10**(-2) 
step_size = 1/L * 4   #2.5 * 1/(L)*1000000000   #1/L_i_max  #1.0 / (10*max_squared_sum + lbda)
store_every = 1
n_steps = 1000
rho = 1
n = n
print('dimension:', d)

print("SAGA step-size = %s" % step_size)
visited_distances_str_saga = np.zeros((n_reps, n_steps+1))
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_saga(rho, n, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_saga[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_saga)
# Out:
# dimension: 112
# SAGA step-size = 1.5400554771943713
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a77a56134f3d> in <module>
#      16 visited_distances_str_saga = np.zeros((n_reps, n_steps+1))
#      17 for rep in range(n_reps):
# ---> 18     rep_x_final, rep_visited_points = str_saga(rho, n, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
#      19     rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
#      20     visited_distances_str_saga[rep, :] = rep_visited_distances
#
# ~/Documents/Técnico/Post-Grad/NeurIPS2021/RealDataset/stochastic_methods.py in str_saga(rho, n, x_init, grad_i, store_every, step_size, n_steps, args)
#     523                 averaged_gradient = (1-1/len(sample_set_idxs)) * averaged_gradient
#     524
# ...

# %%
from stochastic_methods import str_saga_COCO
np.random.seed(0)

K = 2
L = L
tol= 10**(1) 

print("SGD step-size = %s" % step_size)
visited_distances_str_saga_COCO2 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_saga_COCO(K, L, tol, rho, n, x_init,  grad_i, store_every, step_size, n_steps, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_saga_COCO2[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_saga_COCO2)

# %%
from stochastic_methods import str_saga_COCO
np.random.seed(0)

K = 4
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_saga_COCO4 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    t = time.time()
    rep_x_final, rep_visited_points = str_saga_COCO(K, L, tol, rho, n, x_init,  grad_i, store_every, step_size, n_steps, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_saga_COCO4[rep, :] = rep_visited_distances
    #if (rep+1) % 25 == 0:
    #    print(rep+1)
    elapsed = time.time() - t
    print("rep:", rep+1, "- time:", elapsed)

print(visited_distances_str_saga_COCO4)

# %%
from stochastic_methods import str_saga_COCO
np.random.seed(0)

K = 8
L = L
tol= 10**(0) 

print("SGD step-size = %s" % step_size)
visited_distances_str_saga_COCO8 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    t = time.time()
    rep_x_final, rep_visited_points = str_saga_COCO(K, L, tol, rho, n, x_init,  grad_i, store_every, step_size, n_steps, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_saga_COCO8[rep, :] = rep_visited_distances
    #if (rep+1) % 25 == 0:
    #    print(rep+1)
    elapsed = time.time() - t
    print("rep:", rep+1, "- time:", elapsed)

print(visited_distances_str_saga_COCO8)

# %%
from stochastic_methods import str_saga_COCO
np.random.seed(0)

K = 16
L = L
tol= 10**(1) 

print("SGD step-size = %s" % step_size)
visited_distances_str_saga_COCO16 = np.zeros((n_reps, n_steps+1)) 
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_saga_COCO(K, L, tol, rho, n, x_init,  grad_i, store_every, step_size, n_steps, args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_saga_COCO16[rep, :] = rep_visited_distances
    if (rep+1) % 5 == 0:
        print(rep+1)

print(visited_distances_str_saga_COCO16)

# %%
def plot_epochs(visited_distances_mtxs, solvers):
    
    fig, ax = plt.subplots(figsize=(20, 12))
    linestyles = ['-', '--', '--', '-.', ':', '--', '-', '--', '--', '-.', ':', '--', '-']
    ls = 0
    x = np.arange(n_steps+1)
    for mtx in visited_distances_mtxs:
        mean = np.mean(mtx, axis=0)
        std = np.std(mtx, axis=0)/math.sqrt(n_reps)
        
        ax.errorbar(x, mean, xerr=0, yerr=std, linestyle=linestyles[ls])
        #plt.semilogy(mean, lw=2, linestyle = linestyles[ls])
        #ax.set_title('Logistic Regression - Streaming 1st Order')
        ax.set_yscale('log')
        plt.xlabel("Oracle Consultations", fontsize=40)#, fontsize=20)
        plt.ylabel("$E[\|x_k - x^*\|_2]$ ", fontsize=40)#, fontsize=20)
        ls +=1

    plt.xticks(fontsize=40)
    plt.yticks(fontsize=40)
    plt.legend(solvers, fontsize=40)
    plt.xlim([0, 1000])
    plt.ylim([9*10**(-2), 1*10**(0)])
    plt.savefig('mushrooms_strsaga.pdf', bbox_inches='tight')

monitors = [visited_distances_str_saga, visited_distances_str_saga_COCO2, visited_distances_str_saga_COCO4, visited_distances_str_saga_COCO8]#, visited_distances_str_saga_COCO16,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4, visited_distances_str_accsgd, visited_distances_str_accsgd_COCO2, visited_distances_str_accsgd_COCO4]#, monitor_sag] #monitor_gd, monitor_agd,   
solvers = ["STRSAGA", "STRSAGA$+$COCO$_2$", "STRSAGA$+$COCO$_4$", "STRSAGA$+$COCO$_8$", "STRSAGA$+$COCO$_16$"]
plot_epochs(monitors, solvers)

# %% [markdown]
# # Lixo

# %%
def plot_epochs(visited_distances_mtxs, solvers):
    
    fig, ax = plt.subplots(figsize=(15, 12))
    linestyles = ['-', '--', '--', '-.', ':', '--', '-']
    ls = 0
    x = np.arange(n_steps+1)
    for mtx in visited_distances_mtxs:
        mean = np.mean(mtx, axis=0)
        std = np.std(mtx, axis=0)/math.sqrt(n_reps)
        
        ax.errorbar(x, mean, xerr=0, yerr=std, linestyle=linestyles[ls])
        #plt.semilogy(mean, lw=2, linestyle = linestyles[ls])
        ax.set_title('Errorbar upper and lower limits')
        #ax.set_yscale('log')
        plt.xlabel("Gradient Evaluations")
        plt.ylabel("$\|x_k - x^*\|_2$")
        ls +=1

    plt.legend(solvers)
    #plt.xlim([0, 800])
    plt.savefig('plot.png')

monitors = [visited_distances_str_sgd, visited_distances_str_sgd_COCO2, visited_distances_str_sgd_COCO4,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4, ]#, monitor_sag] #monitor_gd, monitor_agd,   
solvers = ["SGD","COCO2", "COCO4", "STRSAGA1", "STRSAGA2", "STRSAGA4"]#, "$SAG$"] #"GD", "AGD"    
plot_epochs(monitors, solvers)

# %%
def plot_epochs(visited_distances_mtxs, solvers):
    
    fig, ax = plt.subplots(figsize=(15, 12))
    linestyles = ['-', '--', '--', '-.', ':', '--', '-']
    ls = 0
    x = np.arange(n_steps+1)
    for mtx in visited_distances_mtxs:
        mean = np.mean(mtx, axis=0)
        std = np.std(mtx, axis=0)/math.sqrt(n_reps)
        
        ax.errorbar(x, mean, xerr=0, yerr=std, linestyle=linestyles[ls])
        #plt.semilogy(mean, lw=2, linestyle = linestyles[ls])
        ax.set_title('Errorbar upper and lower limits')
        ax.set_yscale('log')
        plt.xlabel("Gradient Evaluations")
        plt.ylabel("$\|x_k - x^*\|_2$")
        ls +=1

    plt.legend(solvers)
    #plt.xlim([0, 800])
    plt.savefig('plot_log_COCOs.png')

monitors = [visited_distances_str_sgd, visited_distances_str_sgd_COCO2, visited_distances_str_sgd_COCO4]#,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4, ]#, monitor_sag] #monitor_gd, monitor_agd,   
solvers = ["SGD","COCO2", "COCO4"]#, "STRSAGA1", "STRSAGA2", "STRSAGA4"]#, "$SAG$"] #"GD", "AGD"    
plot_epochs(monitors, solvers)

# %%
def plot_epochs(visited_distances_mtxs, solvers):
    
    fig, ax = plt.subplots(figsize=(15, 12))
    linestyles = ['-', '--', '--', '-.', ':', '--', '-']
    ls = 0
    x = np.arange(n_steps+1)
    for mtx in visited_distances_mtxs:
        mean = np.mean(mtx, axis=0)
        std = np.std(mtx, axis=0)/math.sqrt(n_reps)
        
        ax.errorbar(x, mean, xerr=0, yerr=std, linestyle=linestyles[ls])
        #plt.semilogy(mean, lw=2, linestyle = linestyles[ls])
        ax.set_title('Errorbar upper and lower limits')
        ax.set_yscale('log')
        plt.xlabel("Gradient Evaluations")
        plt.ylabel("$\|x_k - x^*\|_2$")
        ls +=1

    plt.legend(solvers)
    #plt.xlim([0, 800])
    plt.savefig('plot_log_strsagas.png')

monitors = [visited_distances_str_sgd,  visited_distances_str_saga_rho1, visited_distances_str_saga_rho2, visited_distances_str_saga_rho4 ]#, monitor_sag] #monitor_gd, monitor_agd,   , visited_distances_str_sgd_COCO2, visited_distances_str_sgd_COCO4
solvers = ["SGD", "STRSAGA1", "STRSAGA2", "STRSAGA4"]#, "$SAG$"] #"GD", "AGD"    ,"COCO2", "COCO4"
plot_epochs(monitors, solvers)

# %%
from stochastic_methods import str_saga
np.random.seed(0)

rho = 2 
n = n

print("SAGA step-size = %s" % step_size)
visited_distances_str_saga_rho2 = np.zeros((n_reps, n_steps+1))
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_saga(rho, n, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_saga_rho2[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_saga_rho2)

# %%
from stochastic_methods import str_saga
np.random.seed(0)

rho = 4 
n = n

print("SAGA step-size = %s" % step_size)
visited_distances_str_saga_rho4 = np.zeros((n_reps, n_steps+1))
for rep in range(n_reps):
    rep_x_final, rep_visited_points = str_saga(rho, n, x_init, grad_i, store_every, step_size, n_steps,  args=(A, b, lbda))
    rep_visited_distances = [ np.linalg.norm(visited_point - x_min) for visited_point in rep_visited_points]
    visited_distances_str_saga_rho4[rep, :] = rep_visited_distances
    if (rep+1) % 25 == 0:
        print(rep+1)

print(visited_distances_str_saga_rho4)

# %% [markdown]
# # Save/Load variables

# %%
import pickle

# %%
#Save variables 

#with open('mushrooms_visited_distances_str_sgd', 'wb') as f:
#    pickle.dump([visited_distances_str_sgd, visited_distances_str_sgd_COCO2, visited_distances_str_sgd_COCO4, visited_distances_str_sgd_COCO8], f)

#with open('mushrooms_visited_distances_str_adam', 'wb') as f:
#    pickle.dump([visited_distances_str_adam, visited_distances_str_adam_COCO2, visited_distances_str_adam_COCO4, visited_distances_str_adam_COCO8], f)

#with open('mushrooms_visited_distances_str_saga', 'wb') as f:
    #pickle.dump([visited_distances_str_saga, visited_distances_str_saga_COCO2, visited_distances_str_saga_COCO4, visited_distances_str_saga_COCO8], f)

# %%
# Load variables
with open('mushrooms_visited_distances_str_sgd', 'rb') as f:
    visited_distances_str_sgd, visited_distances_str_sgd_COCO2, visited_distances_str_sgd_COCO4, visited_distances_str_sgd_COCO8 = pickle.load(f)

with open('mushrooms_visited_distances_str_adam', 'rb') as f:    
    visited_distances_str_adam, visited_distances_str_adam_COCO2, visited_distances_str_adam_COCO4, visited_distances_str_adam_COCO8 = pickle.load(f)

with open('mushrooms_visited_distances_str_saga', 'rb') as f:
    visited_distances_str_saga, visited_distances_str_saga_COCO2, visited_distances_str_saga_COCO4, visited_distances_str_saga_COCO8= pickle.load(f)
